# %% [markdown]
# # Sequence Modify Maths Operators
#
# In this notebook you will edit working programs so they use maths operators correctly.
#
# > 💡 **Stuck?** Use the [Arithmetic Cheatsheet](../../additional-resources/ARITHMETIC_CHEATSHEET.md) to remind yourself what each operator does.
#
# ## What you will practise
# - Floor division `//` to get whole groups only.
# - Modulus `%` to find what is left over.
# - `round(value, places)` to control decimal places.
#
# ## How to work
# 1. Read the task and expected output carefully.
# 2. Change the starter code so the output matches exactly.
# 3. Focus on the operator named in each task.
# 4. Keep your code in sequence only: no `if`, loops, or functions.

# %% [markdown]
# ## Exercise 1 — Full groups only
#
# **Working code:**
# ```python
# students = 29
# group_size = 4
# full_groups = students / group_size
# print("Full groups: " + str(full_groups))
# ```
#
# **Task:** Change the calculation so it uses floor division `//`. This gives only whole groups and drops the decimal part. We do this because you cannot have part of a student in a group.
#
# **Expected output:**
# ```
# Full groups: 7
# ```

# %%
# Exercise 1 — YOUR CODE
# Use // so the answer is a whole number of groups
students = 29
group_size = 4
full_groups = students / group_size
print("Full groups: " + str(full_groups))

# %% [markdown]
# ## Exercise 2 — Find the leftover
#
# **Working code:**
# ```python
# cupcakes = 29
# per_box = 4
# leftover = 0
# print("Leftover cupcakes: " + str(leftover))
# ```
#
# **Task:** Replace `leftover = 0` so it uses modulus `%`. Modulus gives the remainder after making full groups.
#
# **Expected output:**
# ```
# Leftover cupcakes: 1
# ```

# %%
# Exercise 2 — YOUR CODE
# Use % to work out what is left after full boxes
cupcakes = 29
per_box = 4
leftover = 0
print("Leftover cupcakes: " + str(leftover))

# %% [markdown]
# ## Exercise 3 — Complete teams
#
# **Working code:**
# ```python
# players = 23
# team_size = 5
# complete_teams = players / team_size
# print("Complete teams: " + str(complete_teams))
# ```
#
# **Task:** Change the division to floor division `//` so the answer is only full teams.
#
# **Expected output:**
# ```
# Complete teams: 4
# ```

# %%
# Exercise 3 — YOUR CODE
# Use // so only complete teams are counted
players = 23
team_size = 5
complete_teams = players / team_size
print("Complete teams: " + str(complete_teams))

# %% [markdown]
# ## Exercise 4 — Leftover stickers
#
# **Working code:**
# ```python
# stickers = 23
# stickers_per_sheet = 6
# leftover = 0
# print("Leftover stickers: " + str(leftover))
# ```
#
# **Task:** Use modulus `%` to find how many stickers are left after full sheets.
#
# **Expected output:**
# ```
# Leftover stickers: 5
# ```

# %%
# Exercise 4 — YOUR CODE
# Use % for the remainder
stickers = 23
stickers_per_sheet = 6
leftover = 0
print("Leftover stickers: " + str(leftover))

# %% [markdown]
# ## Exercise 5 — Round an average to 1 decimal place
#
# **Working code:**
# ```python
# total_points = 20
# games = 3
# average_points = total_points / games
# print("Average points: " + str(average_points))
# ```
#
# **Task:** Keep the average calculation, then round it to 1 decimal place with `round(average_points, 1)` before printing.
#
# **Expected output:**
# ```
# Average points: 6.7
# ```

# %%
# Exercise 5 — YOUR CODE
# Round the average to 1 decimal place
total_points = 20
games = 3
average_points = total_points / games
print("Average points: " + str(average_points))

# %% [markdown]
# ## Exercise 6 — Round money to 2 decimal places
#
# **Working code:**
# ```python
# price = 1.257
# amount = 3
# total = price * amount
# print("Total cost: £" + str(total))
# ```
#
# **Task:** Keep the multiplication, then round `total` to 2 decimal places before printing. Use `round(total, 2)` so money is shown neatly.
#
# **Expected output:**
# ```
# Total cost: £3.77
# ```

# %%
# Exercise 6 — YOUR CODE
# Round total to 2 decimal places for money
price = 1.257
amount = 3
total = price * amount
print("Total cost: £" + str(total))

# %% [markdown]
# ## Exercise 7 — Split minutes into hours and minutes
#
# **Working code:**
# ```python
# minutes = 125
# hours = minutes / 60
# minutes_left = minutes - 60
# print(str(minutes) + " minutes is " + str(hours) + " hours and " + str(minutes_left) + " minutes")
# ```
#
# **Task:** Change `hours` to use floor division `//` for full hours. Then use modulus `%` for `minutes_left` so it shows only the leftover minutes.
#
# **Expected output:**
# ```
# 125 minutes is 2 hours and 5 minutes
# ```

# %%
# Exercise 7 — YOUR CODE
# Use // for full hours and % for leftover minutes
minutes = 125
hours = minutes / 60
minutes_left = minutes - 60
print(str(minutes) + " minutes is " + str(hours) + " hours and " + str(minutes_left) + " minutes")

# %% [markdown]
# ## Exercise 8 — Convert pence into pounds and pence
#
# **Working code:**
# ```python
# pence = 389
# pounds = pence / 100
# leftover_pence = 0
# print(str(pence) + "p is £" + str(pounds) + " and " + str(leftover_pence) + "p")
# ```
#
# **Task:** Use floor division `//` to get whole pounds, and modulus `%` to get pence left over.
#
# **Expected output:**
# ```
# 389p is £3 and 89p
# ```

# %%
# Exercise 8 — YOUR CODE
# Use // for pounds and % for leftover pence
pence = 389
pounds = pence / 100
leftover_pence = 0
print(str(pence) + "p is £" + str(pounds) + " and " + str(leftover_pence) + "p")

# %% [markdown]
# ## Exercise 9 — Round average speed
#
# **Working code:**
# ```python
# distance = 86.25
# time_hours = 2
# speed = distance / time_hours
# print("Average speed: " + str(speed) + " km/h")
# ```
#
# **Task:** Keep the speed calculation, then round `speed` to 1 decimal place so the answer is neat and easy to read.
#
# **Expected output:**
# ```
# Average speed: 43.1 km/h
# ```

# %%
# Exercise 9 — YOUR CODE
# Round speed to 1 decimal place
distance = 86.25
time_hours = 2
speed = distance / time_hours
print("Average speed: " + str(speed) + " km/h")

# %% [markdown]
# ## Exercise 10 — Mixed challenge
#
# **Working code:**
# ```python
# crayons = 26
# per_box = 4
# total_price = 10.99
#
# full_boxes = crayons / per_box
# leftover = crayons - per_box
# price_per_box = total_price / full_boxes
#
# print("Full boxes: " + str(full_boxes))
# print("Leftover crayons: " + str(leftover))
# print("Price per box: £" + str(price_per_box))
# ```
#
# **Task:** Fix all three calculations: use floor division `//` for full boxes, modulus `%` for leftover crayons, and `round(..., 2)` for price per box.
#
# **Expected output:**
# ```
# Full boxes: 6
# Leftover crayons: 2
# Price per box: £1.83
# ```

# %%
# Exercise 10 — YOUR CODE
# Fix all three: //, %, and rounding to 2 decimal places
crayons = 26
per_box = 4
total_price = 10.99

full_boxes = crayons / per_box
leftover = crayons - per_box
price_per_box = total_price / full_boxes

print("Full boxes: " + str(full_boxes))
print("Leftover crayons: " + str(leftover))
print("Price per box: £" + str(price_per_box))

# %%
# Self-check scratch cell (not graded)
# You can run small experiments here.

# %%
from exercise_runtime_support.student_checker import run_notebook_checks

# Pass the canonical exercise_key here; do not pass a notebook path.
run_notebook_checks('ex012_sequence_modify_maths_operators')
# Out:
# +-------------+---------------+----------+----------------------------------------+
# | Exercise    | Check         | Status   | Error                                  |
# +=============+===============+==========+========================================+
# | Exercise 1  | Static output | 🔴 NO    | expected 'Full groups: 7'.             |
# +-------------+---------------+----------+----------------------------------------+
# | Exercise 2  | Static output | 🔴 NO    | expected 'Leftover cupcakes: 1'.       |
# +-------------+---------------+----------+----------------------------------------+
# | Exercise 3  | Static output | 🔴 NO    | expected 'Complete teams: 4'.          |
# +-------------+---------------+----------+----------------------------------------+
# | Exercise 4  | Static output | 🔴 NO    | expected 'Leftover stickers: 5'.       |
# +-------------+---------------+----------+----------------------------------------+
# ...

# %% [markdown]
# # Sequence Make Consolidation
#
# ## Goal
# Write short Python programs from scratch using the sequence skills you have already practised.
#
# ## Skills you will use
# - `print()` for output
# - variables to store values
# - `input()` to read text from the user
# - `+`, `-`, `*`, and `/` for calculations
# - `int()`, `float()`, and `str()` when you need to convert data
#
# ## How to work
# - Read the markdown before each exercise cell carefully.
# - Keep each answer inside its tagged code cell.
# - Run the final checker cell when you want quick feedback.
# - Each exercise runs on its own, so do not rely on variables from another cell.

# %% [markdown]
# ## Exercise 1
# Create a short program that stores the words `Oakwood`, `Coding`, and `Club` in separate variables.
# Print exactly one line:
#
# `Welcome to Oakwood Coding Club!`
#
# Use the variables to build the message.

# %%
# Exercise 1
# Store the words in variables, then print the welcome message.

# Write your code below.

# %% [markdown]
# ## Exercise 2
# A snack box contains 4 muffins and each muffin costs 2 pounds.
# Write a program that:
# - stores the snack name, quantity, and price in variables
# - works out the total cost
# - prints exactly these two lines:
#
# `Snack box: muffins`
# `Total cost: 8 pounds`

# %%
# Exercise 2
# Create variables for the snack box and print the two required lines.

# Write your code below.

# %% [markdown]
# ## Exercise 3
# Write a program that asks the user for their name and favourite hobby.
# Then print exactly one line in this style:
#
# `Hello Aisha! Your hobby is drawing.`
#
# Use `print()` before each `input()` so the prompts appear in the output.

# %%
# Exercise 3
# Ask for the name and hobby, then print the final sentence.

# Write your code below.

# %% [markdown]
# ## Exercise 4
# Write a program that asks for the number of books read in one week and the number of weeks.
# Convert both answers to integers, work out the total books read, and print exactly:
#
# `Books read altogether: 18`
#
# Example: if the user enters `6` and `3`, the final line should be `Books read altogether: 18`.

# %%
# Exercise 4
# Ask for the weekly number and the number of weeks, convert them, and print the total.

# Write your code below.

# %% [markdown]
# ## Exercise 5
# Write a program that asks for the distance of one walk in kilometres and the number of walks completed.
# Convert the distance to a float and the number of walks to an integer.
# Work out the total distance and print exactly:
#
# `Total distance: 7.5 km`
#
# Example: if the user enters `2.5` and `3`, the final line should be `Total distance: 7.5 km`.

# %%
# Exercise 5
# Ask for the walk distance and number of walks, convert them, and print the total distance.

# Write your code below.

# %%
# Optional self-check (not graded)
# Try a tiny experiment here if you want to test a calculation or a message format.

# %%
from exercise_runtime_support.student_checker import run_notebook_checks

# Pass the canonical exercise_key here; do not pass a notebook path.
run_notebook_checks('ex008_sequence_make_consolidation')

# %% [markdown]
# # Sequence Modification Basics
#
# Welcome to your first Python exercises! In these activities, you will modify working code to produce different output. Each exercise shows you code that works, and your task is to change it to meet the new requirements.
#
# ## What you'll practice
# - Printing text with `print()`
# - Simple arithmetic
# - String concatenation (joining text together)
#
# ## How to work
# 1. Read the task description for each exercise
# 2. Look at the working code provided
# 3. Modify the code in the tagged cell to produce the expected output
# 4. The output shows you exactly what should appear when you run the code
#
# **Remember**: At this stage, we're just using `print()` statements — no variables yet!

# %% [markdown]
# ## Exercise 1 — Change the greeting
#
# **Working code:**
# ```python
# print("Hello World!")
# ```
#
# **Task:** Modify the code so it prints `Hello Python!` instead.
#
# **Expected output:**
# ```
# Hello Python!
# ```

# %%
# Exercise 1 — YOUR CODE
# Modify the print statement below
print("Hello World!")

# %% [markdown]
# ## Exercise 2 — Print your school
#
# **Working code:**
# ```python
# print("I go to Greenfield School")
# ```
#
# **Task:** Modify the code so it prints `I go to Bassaleg School` instead.
#
# **Expected output:**
# ```
# I go to Bassaleg School
# ```

# %%
# Exercise 2 — YOUR CODE
# Modify the print statement below
print("I go to Greenfield School")

# %% [markdown]
# ## Exercise 3 — Simple arithmetic
#
# **Working code:**
# ```python
# print(5 + 3)
# ```
#
# **Task:** Modify the code so it prints the result of `5 × 3` instead (multiplication uses the `*` symbol in Python).
#
# **Expected output:**
# ```
# 15
# ```

# %%
# Exercise 3 — YOUR CODE
# Modify the arithmetic below
print(5 + 3)

# %% [markdown]
# ## Exercise 4 — String concatenation
#
# **Working code:**
# ```python
# print("Hello" + " " + "World")
# ```
#
# **Task:** Modify the code so it prints `Good Morning Everyone` (three words joined together with spaces).
#
# **Expected output:**
# ```
# Good Morning Everyone
# ```

# %%
# Exercise 4 — YOUR CODE
# Modify the concatenation below
print("Hello" + " " + "World")

# %% [markdown]
# ## Exercise 5 — Change the calculation
#
# **Working code:**
# ```python
# print(10 - 4)
# ```
#
# **Task:** Modify the code so it prints the result of `10 ÷ 2` (division uses the `/` symbol in Python).
#
# **Expected output:**
# ```
# 5.0
# ```
#
# **Note:** Division in Python always produces a decimal number (that's why you see `5.0` instead of `5`).

# %%
# Exercise 5 — YOUR CODE
# Modify the calculation below
print(10 - 4)

# %% [markdown]
# ## Exercise 6 — Multiple print statements
#
# **Working code:**
# ```python
# print("Learning")
# # add two more print() lines below to complete the output
# ```
#
# **Task:** Add the missing print statements so the three lines together say `Learning to code rocks`.
#
# **Expected output:**
# ```
# Learning
# to
# code rocks
# ```
#
# **Note:** The last print statement should output two words!

# %%
# Exercise 6 — YOUR CODE
# Add two more print() statements so the output is:
# Learning
# to
# code rocks
print("Learning")

# TODO: add the two missing print statements below

# %% [markdown]
# ## Exercise 7 — Concatenation with numbers
#
# **Working code:**
# ```python
# print("The result is ")
# # complete the print so it outputs: The result is 100
# ```
#
# **Task:** Modify the code so it prints `The result is 100` (note that `100` should still be in quotes as text).
#
# **Expected output:**
# ```
# The result is 100
# ```

# %%
# Exercise 7 — YOUR CODE
# Complete the print statement below so it produces:
# The result is 100
print("The result is ")

# TODO: add the rest of the print (concatenate "100" as text)

# %% [markdown]
# ## Exercise 8 — More complex arithmetic
#
# **Working code:**
# ```python
# print(2 + 3 + 4)
# ```
#
# **Task:** Modify the code so it prints the result of `2 × 3 × 4`.
#
# **Expected output:**
# ```
# 24
# ```

# %%
# Exercise 8 — YOUR CODE
# Modify the calculation below
print(2 + 3 + 4)

# %% [markdown]
# ## Exercise 9 — Combining text and arithmetic
#
# **Working code:**
# ```python
# print("10 minus 3 equals")
# # add a print() below that performs the calculation inside print()
# ```
#
# **Task:** Modify the code so the first line says `10 minus 3 equals` and the second line shows the result of that calculation.
#
# **Expected output:**
# ```
# 10 minus 3 equals
# 7
# ```

# %%
# Exercise 9 — YOUR CODE
# Modify the statements below
print("10 minus 3 equals")
# The calculation must be performed inside the print() call; do not just print "7"
# TODO: add the print(...) with 10 - 3

# %% [markdown]
# ## Exercise 10 — Build a longer message
#
# **Working code:**
# ```python
# print("Welcome")
# # join the remaining parts using + to make one long message
# ```
#
# **Task:** Modify the code so it prints `Welcome to Python programming!` (five parts joined together: "Welcome", " ", "to", " ", "Python programming!").
#
# **Expected output:**
# ```
# Welcome to Python programming!
# ```

# %%
# Exercise 10 — YOUR CODE
# Add the rest of the concatenation so it prints:
# Welcome to Python programming!
print("Welcome")

# TODO: complete the concatenation on the line below

# %%
# Optional self-check (not graded)
# Try experimenting with print statements here!
# For example:
# print("My first Python program!")
# print(100 + 200)
# print("Score: " + "500")

# %%
from exercise_runtime_support.student_checker import run_notebook_checks

run_notebook_checks('ex002_sequence_modify_basics')
# Out:
# +-------------+------------+----------+---------+
# | Exercise    | Check      | Status   | Error   |
# +=============+============+==========+=========+
# | Exercise 1  | exercise1  | 🟢 OK    |         |
# +-------------+------------+----------+---------+
# | Exercise 2  | exercise2  | 🟢 OK    |         |
# +-------------+------------+----------+---------+
# | Exercise 3  | exercise3  | 🟢 OK    |         |
# +-------------+------------+----------+---------+
# | Exercise 4  | exercise4  | 🟢 OK    |         |
# +-------------+------------+----------+---------+
# | Exercise 5  | exercise5  | 🟢 OK    |         |
# +-------------+------------+----------+---------+
# | Exercise 6  | exercise6  | 🟢 OK    |         |
# +-------------+------------+----------+---------+
# | Exercise 7  | exercise7  | 🟢 OK    |         |
# +-------------+------------+----------+---------+
# | Exercise 8  | exercise8  | 🟢 OK    |         |
# +-------------+------------+----------+---------+
# ...

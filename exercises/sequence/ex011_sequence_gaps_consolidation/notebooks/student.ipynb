# %% [markdown]
# # Sequence Gaps Consolidation
#
# ## Goal
# Use the sequence skills you have already learned to fill in the missing code lines.
#
# ## How to work
# - Read the expected output before you write anything.
# - Find the `# YOUR CODE HERE` comment in each exercise cell.
# - Delete the comment and write the missing line(s) in its place.
# - Each exercise stands on its own, so do not rely on variables from another cell.
# - From the repository root, run `uv run pytest -q exercises/sequence/ex011_sequence_gaps_consolidation/tests/test_ex011_sequence_gaps_consolidation.py`.

# %% [markdown]
# ## Exercise 1 - Build a sentence
# Fill in the missing line so the program prints one exact line.
#
# **Expected output:**
# ```
# Sequence is fun
# ```

# %%
word_one = "Sequence"
word_two = "is"
word_three = "fun"
# YOUR CODE HERE - join the words into a message and print it
print(message)

# %% [markdown]
# ## Exercise 2 - Use a variable
# Fill in the missing line so the program prints `Hello Amina`.
#
# **Expected output:**
# ```
# Hello Amina
# ```

# %%
greeting = "Hello"
name = "Amina"
# YOUR CODE HERE - combine the greeting and the name into one message
print(message)

# %% [markdown]
# ## Exercise 3 - Read one word
# Type your favourite word when asked. The program should echo it in a short sentence.
#
# **Expected output:**
# ```
# What is your favourite word? [Input: coding]
# You chose coding
# ```

# %%
print("What is your favourite word?")
word = input()
# YOUR CODE HERE - print a sentence that includes word

# %% [markdown]
# ## Exercise 4 - Add two numbers
# Fill in the missing lines so the program calculates the total of two numbers and prints it.
#
# **Expected output:**
# ```
# The total is 10
# ```

# %%
first_number = 4
second_number = 6
# YOUR CODE HERE - calculate the total
print(f"The total is {total}")

# %% [markdown]
# ## Exercise 5 - Find the total cost
# The program should work out the cost of several items.
#
# **Expected output:**
# ```
# Total cost: 7.5
# ```

# %%
price = 2.5
item_count = 3
# YOUR CODE HERE - calculate the total cost
print(f"Total cost: {total_cost}")

# %% [markdown]
# ## Exercise 6 - Average distance
# Work out the average distance per day.
#
# **Expected output:**
# ```
# Average distance: 3.5 km
# ```

# %%
total_distance = 7
days = 2
# YOUR CODE HERE - calculate the average distance per day
print(f"Average distance: {average_distance} km")

# %% [markdown]
# ## Exercise 7 - Share a hobby
# Use the values already stored in the program to print one full sentence.
#
# **Expected output:**
# ```
# Aisha enjoys drawing after school.
# ```

# %%
first_name = "Aisha"
hobby = "drawing"
# YOUR CODE HERE - create a message with the values and print it
print(message)

# %% [markdown]
# ## Exercise 8 - Greet a visitor
# Ask for a first name and a town, then print one sentence that includes both values.
#
# **Expected output:**
# ```
# Enter your first name: [Input: Aisha]
# Enter your town: [Input: Cardiff]
# Hello Aisha from Cardiff.
# ```

# %%
print("Enter your first name:")
first_name = input()
print("Enter your town:")
town = input()
# YOUR CODE HERE - print a sentence that includes both values

# %% [markdown]
# ## Exercise 9 - Favourite things
# Ask for two favourite things and print one sentence that uses both answers.
#
# **Expected output:**
# ```
# Enter your favourite colour: [Input: blue]
# Enter your favourite animal: [Input: fox]
# My favourite colour is blue and my favourite animal is fox.
# ```

# %%
print("Enter your favourite colour:")
colour = input()
print("Enter your favourite animal:")
animal = input()
# YOUR CODE HERE - print a sentence that uses both answers

# %% [markdown]
# ## Exercise 10 - Sequence shop total
# Use the values already stored in the program to work out the total cost and print the final message.
#
# **Expected output:**
# ```
# Enter your name: [Input: Amina]
# Welcome to Sequence Supplies, Amina. Your total is £14.0.
# ```

# %%
shop_name = "Sequence Supplies"
print("Enter your name:")
customer_name = input()
notebook_price = 3.5
notebook_count = 4
# YOUR CODE HERE - calculate the total cost and print the final message

# %%
# Self-check scratch cell (not graded)
# You can run small experiments here.

# %%
from exercise_runtime_support.student_checker import run_notebook_checks

# Pass the canonical exercise_key here; do not pass a notebook path.
run_notebook_checks('ex011_sequence_gaps_consolidation')

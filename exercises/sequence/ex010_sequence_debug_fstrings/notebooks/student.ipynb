# %% [markdown]
# # Sequence Debug F-Strings
#
#
#
# In this notebook, you will debug short sequence programs that use f-strings.
#
#
#
# For each exercise:
#
# - Run the code.
#
# - Compare the result with the expected output.
#
# - Fix the code in the tagged cell.
#
# - Write a short explanation of what went wrong in the reflection cell.
#
#
#
# The first exercises each have one main bug. The later exercises may need two or three small fixes.

# %% [markdown]
# ## Exercise 1 - Welcome message
#
#
#
# This program should print a welcome message using the variable value.
#
#
#
# **Expected output:**
#
#
#
# ```text
#
# Welcome, Sam!
#
# ```

# %%
name = "Sam"

print("Welcome, {name}!")

# %% [markdown]
# ### What actually happened
#
#
#
# Describe the problem you saw when you ran the code, and explain how you fixed it.

# %% [markdown]
# ## Exercise 2 - Pet sentence
#
#
#
# This program should print the pet stored in the variable.
#
#
#
# **Expected output:**
#
#
#
# ```text
#
# My pet is a rabbit!
#
# ```

# %%
pet = "rabbit"

print(f"My pet is a {animal}!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 pet = "rabbit"
# ----> 3 print(f"My pet is a {animal}!")
#
# NameError: name 'animal' is not defined

# %% [markdown]
# ### What actually happened
#
#
#
# Describe the problem you saw when you ran the code, and explain how you fixed it.

# %% [markdown]
# ## Exercise 3 - After-school activity
#
#
#
# This program should use both variables in the final sentence.
#
#
#
# **Expected output:**
#
#
#
# ```text
#
# Mia enjoys drawing after school.
#
# ```

# %%
person = "Mia"

hobby = "drawing"

print(f"{person} enjoys hobby after school.")

# %% [markdown]
# ### What actually happened
#
#
#
# Describe the problem you saw when you ran the code, and explain how you fixed it.

# %% [markdown]
# ## Exercise 4 - Favourite lesson
#
#
#
# This program should print the lesson stored in the variable, including the full stop.
#
#
#
# **Expected output:**
#
#
#
# ```text
#
# Our best lesson is computing.
#
# ```

# %%
lesson = "computing"

print(f"Our best lesson is lesson.")

# %% [markdown]
# ### What actually happened
#
#
#
# Describe the problem you saw when you ran the code, and explain how you fixed it.

# %% [markdown]
# ## Exercise 5 - Snack choice
#
#
#
# This program should ask for a snack and print the answer in the final sentence.
#
#
#
# **Expected output:**
#
#
#
# ```text
#
# Type your favourite snack: [Input: popcorn]
#
# You chose popcorn for break time.
#
# ```

# %%
snack = input("Type your favourite snack: ")

print("You chose {snack} for break time.")

# %% [markdown]
# ### What actually happened
#
#
#
# Describe the problem you saw when you ran the code, and explain how you fixed it.

# %% [markdown]
# ## Exercise 6 - Greeting from a town
#
#
#
# This program should use both inputs in the final greeting.
#
#
#
# **Expected output:**
#
#
#
# ```text
#
# Enter your first name: [Input: Aisha]
#
# Enter your town: [Input: Leeds]
#
# Hello Aisha from Leeds.
#
# ```

# %%
name = input("Enter your first name: ")

town = input("Enter your town: ")

print(f"Hello {name} from town.")

# %% [markdown]
# ### What actually happened
#
#
#
# Describe the problem you saw when you ran the code, and explain how you fixed it.

# %% [markdown]
# ## Exercise 7 - Score update
#
#
#
# This program should print the score stored in the variable.
#
#
#
# **Expected output:**
#
#
#
# ```text
#
# You scored 4 goals today.
#
# ```

# %%
goals = 4

print(f"You scored {goals} goal today.")

# %% [markdown]
# ### What actually happened
#
#
#
# Describe the problem you saw when you ran the code, and explain how you fixed it.

# %% [markdown]
# ## Exercise 8 - Ticket total
#
#
#
# This program should add the two ticket values and print the total in the final sentence.
#
#
#
# **Expected output:**
#
#
#
# ```text
#
# Tickets sold altogether: 7
#
# ```

# %%
adult_tickets = 4

child_tickets = 3

total_tickets = adult_tickets - child_tickets

print("Tickets sold altogether: {total_tickets}")

# %% [markdown]
# ### What actually happened
#
#
#
# Describe the problem you saw when you ran the code, and explain how you fixed it.

# %% [markdown]
# ## Exercise 9 - Reading total
#
#
#
# This program should add the two values and print the total pages read.
#
#
#
# **Expected output:**
#
#
#
# ```text
#
# Pages read in two days: 20
#
# ```

# %%
pages_today = 12

pages_tomorrow = 8

total_pages = pages_today - pages_tomorrow

print("Pages read in two days: {total_pages}")

# %% [markdown]
# ### What actually happened
#
#
#
# Describe the problem you saw when you ran the code, and explain how you fixed it.

# %% [markdown]
# ## Exercise 10 - Pencil cost
#
#
#
# This program should work out the total cost and print the number of pencils.
#
#
#
# **Expected output:**
#
#
#
# ```text
#
# Total cost for 6 pencils: £3.0
#
# ```

# %%
price = 0.5

amount = 6

total_cost = price + amount

print(f"Total cost for amount pencils: £{total_cost}")

# %% [markdown]
# ### What actually happened
#
#
#
# Describe the problem you saw when you ran the code, and explain how you fixed it.

# %%
# Self-check scratch cell (not graded)
# You can run small experiments here.

# %%
from exercise_runtime_support.student_checker import run_notebook_checks

# Pass the canonical exercise_key here; do not pass a notebook path.
run_notebook_checks('ex010_sequence_debug_fstrings')
# Out:
# +-------------+-------------+----------+------------------------------------------+
# | Exercise    | Check       | Status   | Error                                    |
# +=============+=============+==========+==========================================+
# | Exercise 1  | Output      | 🔴 NO    | output does not match expected text.     |
# +-------------+-------------+----------+------------------------------------------+
# |             | Construct   | 🔴 NO    | use an f-string in the final output.     |
# +-------------+-------------+----------+------------------------------------------+
# |             | Explanation | 🔴 NO    | explanation needs more detail.           |
# +-------------+-------------+----------+------------------------------------------+
# | Exercise 2  | Output      | 🔴 NO    | Execution failed for code tagged         |
# |             |             |          | 'exercise2' in /workspaces/PythonExercis |
# ...
